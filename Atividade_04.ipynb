# %% [markdown]
# <a href="https://colab.research.google.com/github/danieldosadi/AulaGit/blob/main/Atividade_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar pandas
import pandas as pd

# Passo 2 - Ler arquivo

dados = pd.read_csv('youtube_dislike_dataset.csv')
data_frame
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
# Passo 3 - Converter em DataFrame
data_frame = pd.DataFrame(dados)

# %%
# Passo 4 - Criar Filtro Title, View Count, Likes, Dislikes e Comment Count
coluna_selecionada = data_frame[['title','view_count', 'likes', 'dislikes', 'comment_count']]
coluna_selecionada
# Out:
#                                                    title  view_count    likes  \
# 0                   Jadon Sancho  Magical Skills & Goals     1048888    19515
# 1                     Migos - Avalanche (Official Video)    15352638   359277
# 2             Supporting Actress in a Comedy: 73rd Emmys      925281    11212
# 3                JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO     2641597    39131
# 4                           Why Retaining Walls Collapse      715724    32887
# ...                                                  ...         ...      ...
# 37417  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...   120408275  2180780
# 37418  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...     2841917    20759
# 37419                 [MV]  (MAMAMOO) - Where Are We Now    13346678   720854
# 37420              FELLIPE ESCUDERO- Master Podcast  #12      252057    19198
# 37421  Gareth Bale brace secures dramatic comeback on...     2252090    34063
#
#        dislikes  comment_count
# ...

# %%
# Passo 4 - Criar Filtro Dislikes
filtro_dislikes = coluna_selecionada['dislikes'] < 1000
coluna_selecionada[filtro_dislikes]
# Out:
#                                                    title  view_count  likes  \
# 0                   Jadon Sancho  Magical Skills & Goals     1048888  19515
# 2             Supporting Actress in a Comedy: 73rd Emmys      925281  11212
# 3                JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO     2641597  39131
# 4                           Why Retaining Walls Collapse      715724  32887
# 6      TEST COMPLET du Google Pixel 6 Pro : Une EXPRI...       93337   5595
# ...                                                  ...         ...    ...
# 37410  The Gaines' Living Room Renovation is Complete...      547119   4014
# 37411  La dclaration PARFAITE de Lewandowski qui a fa...      941258  17547
# 37413  Guessing Cheap vs Expensive Items Challenge ft...      484793  21746
# 37415  Highlights: Leeds United 1-0 Burnley | Bamford...      182440   2681
# 37421  Gareth Bale brace secures dramatic comeback on...     2252090  34063
#
#        dislikes  comment_count
# ...

# %%
# Passo 5 -

row, col = coluna_selecionada.shape
row
# Out:
# 37422
